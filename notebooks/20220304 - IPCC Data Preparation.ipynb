# %% [markdown]
# # IPCC Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import json
import os
import bertopic

# %load_ext autoreload
# %autoreload 2

pd.options.display.max_columns = 100

# %%
# tweets.data.to_pickle("../data/FINALDATA.pkl")

# %%
import sys
sys.path.append("../")

import climatewatch

# %%
from climatewatch.data import process_raw_data,process_pretrained_classifiers,process_sentiment_vader
from climatewatch.data import open_jsonl_data

from climatewatch.utils import CodeCarbon

# %% [markdown]
# # Preparing Data from jsonl files

# %%
folder = "../data/IPCC"

with CodeCarbon():
    
    data = []
    
    for name in ["IPCC_WG1","IPCC_WG2","GIEC_WG1","GIEC_WG2"]:
        
        source,wg = name.split("_")
    
        ipcc = open_jsonl_data(os.path.join(folder,f"{name}.json"),encoding = "utf16")
        ipcc = process_raw_data(ipcc)
        ipcc = process_sentiment_vader(ipcc)
        ipcc["source_file"] = name
        ipcc["hashtag"] = source
        ipcc["workgroup"] = wg 
        
        data.append(ipcc)
    
    data = pd.concat(data,ignore_index = True)
    data.to_pickle("../data/IPCC/full_data_without_emotions.pkl")
# Out:
# CODECARBON : No CPU tracking mode found. Falling back on CPU constant mode.
# CODECARBON : Failed to match CPU TDP constant. Falling back on a global constant.
# [INFO] Measuring carbon emissions with CodeCarbon

# %%
data["date"].iloc[0]
# Out:
# Timestamp('2021-08-15 23:51:09+0000', tz='UTC')

# %%
data.loc[data["workgroup"] == "WG1","after_release"] = (data["date"] >= "2021-08-09")
data.loc[data["workgroup"] == "WG2","after_release"] = (data["date"] >= "2022-02-28")

data["date_day"] = pd.to_datetime(data["date"].dt.date)

data.loc[data["workgroup"] == "WG1","date_release_index"] = (data["date_day"] - pd.to_datetime("2021-08-09")).dt.days
data.loc[data["workgroup"] == "WG2","date_release_index"] = (data["date_day"] - pd.to_datetime("2022-02-28")).dt.days

data.loc[data["workgroup"] == "WG1","date_release"] = (data["date"] - pd.to_datetime("2021-08-09 00:00:00+0000"))
data.loc[data["workgroup"] == "WG2","date_release"] = (data["date"] - pd.to_datetime("2022-02-28 00:00:00+0000"))

# %%
data.to_pickle("../data/IPCC/full_data_without_emotions.pkl")

# %%
data.groupby(["workgroup","after_release"])["date"].count()
# Out:
# workgroup  after_release
# WG1        False             1336
#            True             32159
# WG2        False              977
#            True             13519
# Name: date, dtype: int64

# %% [markdown]
# # Quick explo

# %%
data.shape
# Out:
# (47991, 20)

# %%
data["source_file"].value_counts()
# Out:
# IPCC1    26471
# IPCC2    10407
# GIEC1     7024
# GIEC2     4089
# Name: source_file, dtype: int64

# %%
data[["clean_sentiment"]].to_csv("../data/IPCC/full_data_only_text.csv",index = False)

# %% [markdown]
# # Add emotions

# %%
folder = "../data/IPCC"
files = os.listdir(folder)
files = [os.path.join(folder,x) for x in files if x.startswith("emotion") and "emoji" not in x]
files
# Out:
# ['../data/IPCC\\emotions_emotion.csv',
#  '../data/IPCC\\emotions_irony.csv',
#  '../data/IPCC\\emotions_sentiment.csv',
#  '../data/IPCC\\emotions_stance-climate.csv']

# %%
data = pd.read_pickle("../data/IPCC/full_data_without_emotions.pkl")

# %%
all_tasks = []

for task in ["emotion","irony","sentiment","stance-climate"]:
    task_data = pd.read_csv(os.path.join(folder,f"emotions_{task}.csv"))
    task_data = task_data.iloc[:,1:]
    task_data[task.replace("-","_")] = task.replace("-","_") + "_" + task_data.idxmax(axis = 1)
    task_data.columns = [(task.replace("-","_") + "_" + x) if not x.startswith(task) else x for x in task_data.columns]
    
    all_tasks.append(task_data)
all_tasks = pd.concat(all_tasks,axis = 1)

# %%
data = pd.concat([data,all_tasks],axis = 1)

# %%
data
# Out:
#                                                      url  \
# 0      https://twitter.com/7VAMPIR/status/14270552921...
# 1      https://twitter.com/BrianMcHugh2011/status/142...
# 2      https://twitter.com/KenyaEmissionsT/status/142...
# 3      https://twitter.com/fedwer/status/142705395594...
# 4      https://twitter.com/KyleaTink/status/142705044...
# ...                                                  ...
# 47986  https://twitter.com/GARREAU75/status/149565828...
# 47987  https://twitter.com/GARREAU75/status/149565802...
# 47988  https://twitter.com/GARREAU75/status/149565773...
# 47989  https://twitter.com/PCF_82/status/149564711278...
# 47990  https://twitter.com/Zehub/status/1495645657578...
#
#                            date  \
# 0     2021-08-15 23:51:09+00:00
# 1     2021-08-15 23:50:26+00:00
# 2     2021-08-15 23:49:54+00:00
# 3     2021-08-15 23:45:51+00:00
# 4     2021-08-15 23:31:54+00:00
# ...                         ...
# 47986 2022-02-21 07:14:58+00:00
# 47987 2022-02-21 07:13:55+00:00
# 47988 2022-02-21 07:12:47+00:00
# 47989 2022-02-21 06:30:34+00:00
# 47990 2022-02-21 06:24:47+00:00
#
#                                                  content                   id  \
# 0      #IPCCReport2021 #IPCC\n#Klimakatastrophe \nhtt...  1427055292148236290
# 1      We get to decide our future.\n\nIt's up to us ...  1427055109591142403
# 2      Reducing GHG emissions for developing countrie...  1427054977541935112
# 3      Lo que duró la atención que la TV estadouniden...  1427053955947941894
# 4      “As scientists we’ve done our job” …. The #IPC...  1427050447903150082
# ...                                                  ...                  ...
# 47986  #Rapport du #Giec : voici comment la #France p...  1495658288226377730
# 47987  #Rapport du #Giec : voici comment la #France p...  1495658023326523395
# 47988  #Rapport du #Giec : voici comment la #France p...  1495657739925823490
# 47989  #Climat\n💪 Avec @Fabien_Roussel la France se d...  1495647112784191491
# 47990  #Rapport du #Giec : voici comment la France po...  1495645657578754050
#
#        replyCount  retweetCount  likeCount  quoteCount       conversationId  \
# 0               0             0          0           0  1427055292148236290
# 1               0             0          1           0  1427055109591142403
# 2               0             0          0           0  1427054977541935112
# 3               0             0          0           0  1427053955947941894
# 4               0             2          6           0  1427050447903150082
# ...           ...           ...        ...         ...                  ...
# 47986           0             0          1           0  1495658288226377730
# 47987           0             2          2           0  1495658023326523395
# 47988           0             1          2           0  1495657739925823490
# 47989           1            14         21           0  1495647112784191491
# 47990           2             6          5           2  1495645657578754050
#
#       lang                                           outlinks  \
# 0      und                     [https://youtu.be/r7CicXavjH8]
# 1       en                                               None
# 2       en                                               None
# 3       es  [https://twitter.com/AlexSteffen/status/142700...
# 4       en  [https://7ampodcast.com.au/episodes/a-climate-...
# ...    ...                                                ...
# 47986   fr                                               None
# 47987   fr                                               None
# 47988   fr  [https://www.novethic.fr/actualite/environneme...
# 47989   fr  [https://www.fabienroussel2022.fr/47_la_france...
# 47990   fr  [https://www.novethic.fr/actualite/environneme...
#
#                                                 hashtags         username  \
# 0               [IPCCReport2021, IPCC, Klimakatastrophe]          7VAMPIR
# 1      [wildfires, Canada, ClimateEmergency, NoPlanet...  BrianMcHugh2011
# 2      [EmissionsTradingSystemKenya, CarbonPricing, I...  KenyaEmissionsT
# 3          [IPCC, crisisclimatica, disociacioncognitiva]           fedwer
# 4                             [IPCC, ClimateReport, now]        KyleaTink
# ...                                                  ...              ...
# 47986    [Rapport, Giec, France, changement, climatique]        GARREAU75
# 47987    [Rapport, Giec, France, changement, climatique]        GARREAU75
# 47988    [Rapport, Giec, France, changement, climatique]        GARREAU75
# 47989                       [Climat, GIEC, JoursHeureux]           PCF_82
# 47990              [Rapport, Giec, changementclimatique]            Zehub
#
#                                           clean_bertopic  \
# 0                   IPCCReport2021 IPCC Klimakatastrophe
# 1      We get to decide our future. It's up to us to ...
# 2      Reducing GHG emissions for developing countrie...
# 3      Lo que duró la atención que la TV estadouniden...
# 4      “As scientists we’ve done our job” …. The IPCC...
# ...                                                  ...
# 47986  Rapport du Giec : voici comment la France pour...
# 47987  Rapport du Giec : voici comment la France pour...
# 47988  Rapport du Giec : voici comment la France pour...
# 47989  Climat 💪 Avec Fabien_Roussel la France se dote...
# 47990  Rapport du Giec : voici comment la France pour...
#
#                                          clean_sentiment likeCat retweetCat  \
# 0                   IPCCReport2021 IPCC Klimakatastrophe      <5         <5
# 1      We get to decide our future. It's up to us to ...      <5         <5
# 2      Reducing GHG emissions for developing countrie...      <5         <5
# 3      Lo que duró la atención que la TV estadouniden...      <5         <5
# 4      “As scientists we’ve done our job” …. The IPCC...     <50         <5
# ...                                                  ...     ...        ...
# 47986  Rapport du Giec : voici comment la France pour...      <5         <5
# 47987  Rapport du Giec : voici comment la France pour...      <5         <5
# 47988  Rapport du Giec : voici comment la France pour...      <5         <5
# 47989  Climat 💪 Avec @user la France se dotera d'une ...     <50        <50
# 47990  Rapport du Giec : voici comment la France pour...     <50        <50
#
#       vader_sentiment_class  vader_sentiment_score source_file hashtag  \
# 0                   neutral                 0.0000    IPCC_WG1    IPCC
# 1                   neutral                 0.4939    IPCC_WG1    IPCC
# 2                   neutral                 0.9246    IPCC_WG1    IPCC
# 3                   neutral                 0.0000    IPCC_WG1    IPCC
# 4                   neutral                 0.0000    IPCC_WG1    IPCC
# ...                     ...                    ...         ...     ...
# 47986               neutral                 0.0000    GIEC_WG2    GIEC
# 47987               neutral                 0.0000    GIEC_WG2    GIEC
# 47988               neutral                 0.0000    GIEC_WG2    GIEC
# 47989               neutral                 0.0000    GIEC_WG2    GIEC
# 47990               neutral                 0.0000    GIEC_WG2    GIEC
#
#       workgroup after_release  emotion_anger  emotion_joy  emotion_optimism  \
# 0           WG1          True       0.317594     0.238831          0.055110
# 1           WG1          True       0.064742     0.073959          0.509968
# 2           WG1          True       0.077136     0.431390          0.404921
# 3           WG1          True       0.066074     0.054523          0.077113
# 4           WG1          True       0.077985     0.136410          0.720307
# ...         ...           ...            ...          ...               ...
# 47986       WG2         False       0.045647     0.858050          0.063657
# 47987       WG2         False       0.054116     0.813007          0.093716
# 47988       WG2         False       0.054116     0.813007          0.093716
# 47989       WG2         False       0.045427     0.857424          0.060798
# 47990       WG2         False       0.056666     0.806642          0.097136
#
#        emotion_sadness           emotion  irony_non_irony            irony  \
# 0             0.388464   emotion_sadness         0.473522      irony_irony
# 1             0.351330  emotion_optimism         0.911690  irony_non_irony
# 2             0.086553       emotion_joy         0.907990  irony_non_irony
# 3             0.802290   emotion_sadness         0.837189  irony_non_irony
# 4             0.065298  emotion_optimism         0.852641  irony_non_irony
# ...                ...               ...              ...              ...
# 47986         0.032645       emotion_joy         0.919710  irony_non_irony
# 47987         0.039161       emotion_joy         0.882576  irony_non_irony
# 47988         0.039161       emotion_joy         0.882576  irony_non_irony
# 47989         0.036351       emotion_joy         0.914907  irony_non_irony
# 47990         0.039557       emotion_joy         0.836677  irony_non_irony
#
#        sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0                0.030126           0.941534            0.028340
# 1                0.074137           0.727112            0.198751
# 2                0.010140           0.198305            0.791555
# 3                0.023452           0.938772            0.037776
# 4                0.023922           0.619700            0.356378
# ...                   ...                ...                 ...
# 47986            0.013777           0.935062            0.051160
# 47987            0.013084           0.933354            0.053562
# 47988            0.013084           0.933354            0.053562
# 47989            0.013665           0.937661            0.048674
# 47990            0.016711           0.931928            0.051360
#
#                 sentiment  stance_climate_none  stance_climate_against  \
# 0       sentiment_neutral             0.046032                0.035799
# 1       sentiment_neutral             0.017307                0.042754
# 2      sentiment_positive             0.017881                0.039218
# 3       sentiment_neutral             0.018587                0.039982
# 4       sentiment_neutral             0.017357                0.041768
# ...                   ...                  ...                     ...
# 47986   sentiment_neutral             0.953082                0.016740
# 47987   sentiment_neutral             0.952036                0.016551
# 47988   sentiment_neutral             0.952036                0.016551
# 47989   sentiment_neutral             0.955179                0.017443
# 47990   sentiment_neutral             0.951083                0.016289
#
#        stance_climate_favor stance_climate_stance_climate
# 0                  0.918169          stance_climate_favor
# 1                  0.939939          stance_climate_favor
# 2                  0.942901          stance_climate_favor
# 3                  0.941431          stance_climate_favor
# 4                  0.940875          stance_climate_favor
# ...                     ...                           ...
# 47986              0.030177           stance_climate_none
# 47987              0.031413           stance_climate_none
# 47988              0.031413           stance_climate_none
# 47989              0.027378           stance_climate_none
# 47990              0.032627           stance_climate_none
#
# [47991 rows x 38 columns]

# %%
data.to_pickle("../data/IPCC/full_data.pkl")
